# %% [markdown]
# # 気象データから1時間後の降雨を予測する

# %% [markdown]
# 概要：過去の気象データを学習して、現時点の気象データから１時間後の降雨の有無を予測する

# %% [markdown]
# ***

# %% [markdown]
# ## １．データの概要を把握する

# %% [markdown]
# ### CSVファイルからデータを読み込む

# %%
#ライブラリーを読み込む
import pandas as pd
pd.set_option('precision', 2)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import datetime

# データの読込と表示
df_orig = pd.read_csv(
    "17_preprocessed.csv",
    sep="," ,
    skiprows = 1,
    header= 1,
    encoding = "Shift_JISx0213").set_index("年月日時")
df_orig.head()            # 統計量の表示

df_orig = df_orig[24 * 30:-24*30] # 冬は雨ではなく雪のため除く

# %% [markdown]
# ***

# %% [markdown]
# ### 統計データを表示

# %%
df_orig.describe()
# Out:
#          気温(℃)  降水量(mm)    降雪(cm)   積雪(cm)  日照時間(時間)  風速(m/s)       風向  \
# count  7319.00  7319.00  7.32e+03  7319.00   7319.00  7319.00  7319.00
# mean     14.22     0.15  7.65e-03     0.62      0.23     2.49     2.71
# std       9.16     1.09  1.17e-01     2.48      0.38     1.77     1.86
# min      -6.80     0.00  0.00e+00     0.00      0.00     0.00     0.00
# 25%       6.50     0.00  0.00e+00     0.00      0.00     1.10     1.18
# 50%      15.20     0.00  0.00e+00     0.00      0.00     1.90     2.36
# 75%      22.00     0.00  0.00e+00     0.00      0.40     3.60     4.32
# max      34.80    52.00  4.00e+00    21.00      1.00    11.10     5.89
#
#        露点温度(℃)  蒸気圧(hPa)  相対湿度(％)  海面気圧(hPa)  現地気圧(hPa)  日射量(MJ/㎡)       天気  \
# count  7319.00   7319.00  7319.00    7319.00    7319.00    7319.00  7319.00
# mean      9.19     13.48    74.05    1013.34     964.43       0.66     4.17
# std       8.90      7.43    17.06       7.43       6.35       0.97     3.16
# min     -13.30      2.20    12.00     982.40     935.10       0.00     1.00
# 25%       1.20      6.70    63.00    1008.30     960.50       0.00     2.00
# 50%       9.90     12.20    77.00    1012.70     964.30       0.04     4.00
# 75%      16.70     19.00    88.00    1018.70     968.60       1.10     4.00
# max      24.80     31.20   100.00    1030.40     978.70       3.78    15.00
#
#         視程(km)  雲量(10分比)
# count  7319.00   7319.00
# mean     18.62      7.43
# std       7.73      3.57
# min       0.70      0.00
# 25%      15.00      5.00
# 50%      20.00     10.00
# 75%      25.00     10.00
# max      40.00     10.00

# %% [markdown]
# ***

# %% [markdown]
# ### データを標準化する

# %%
df =  (df_orig - df_orig.mean()) / (df_orig.std())
df.head()
# Out:
#                 気温(℃)  降水量(mm)  降雪(cm)  積雪(cm)  日照時間(時間)  風速(m/s)    風向  \
# 年月日時
# 2017/1/31 1:00  -1.70    -0.14   -0.07    4.99     -0.61    -0.39 -1.03
# 2017/1/31 2:00  -1.70    -0.14    8.51    5.39     -0.61     0.34 -1.46
# 2017/1/31 3:00  -1.66    -0.14   -0.07    4.99     -0.61     1.19  1.71
# 2017/1/31 4:00  -1.89    -0.14   -0.07    4.99     -0.61     0.12 -0.82
# 2017/1/31 5:00  -1.89    -0.14   -0.07    4.99     -0.61     2.27 -0.61
#
#                 露点温度(℃)  蒸気圧(hPa)  相対湿度(％)  海面気圧(hPa)  現地気圧(hPa)  日射量(MJ/㎡
# 風速(m/s)      -0.04     -0.06 -4.02e-01  -1.74e-01      -0.16       0.28  0.07
# 風向            0.13      0.12  1.05e-01   4.68e-03       0.03      -0.20 -0.07
# 露点温度(℃)       1.00      0.97  2.35e-01  -5.23e-01      -0.35       0.02  0.06
# 蒸気圧(hPa)      0.97      1.00  2.39e-01  -5.29e-01      -0.36       0.03  0.07
# 相対湿度(％)       0.23      0.24  1.00e+00  -2.53e-04      -0.06      -0.66  0.37
# 海面気圧(hPa)    -0.52     -0.53 -2.53e-04   1.00e+00       0.98      -0.13 -0.18
# 現地気圧(hPa)    -0.35     -0.36 -5.54e-02   9.75e-01       1.00      -0.06 -0.23
# 日射量(MJ/㎡)     0.02      0.03 -6.64e-01  -1.26e-01      -0.06       1.00 -0.18
# 天気            0.06      0.07  3.70e-01  -1.80e-01      -0.23      -0.18  1.00
# 視程(km)       -0.11     -0.10 -2.36e-01   9.00e-02       0.10      -0.05 -0.39
# 雲量(10分比)      0.29      0.29  2.80e-01  -2.60e-01      -0.25      -0.18  0.55
#
#              視程(km)  雲量(10分比)
# 気温(℃)     -1.69e-02  1.68e-01
# 降水量(mm)   -9.22e-02  7.88e-02
# 降雪(cm)    -7.72e-02  4.12e-02
# 積雪(cm)    -5.65e-03 -6.18e-02
# 日照時間(時間)   5.66e-02 -3.26e-01
# 風速(m/s)    1.57e-01  3.46e-02
# 風向         2.14e-03  8.61e-03
# 露点温度(℃)   -1.09e-01  2.94e-01
# 蒸気圧(hPa)  -1.04e-01  2.89e-01
# 相対湿度(％)   -2.36e-01  2.80e-01
# 海面気圧(hPa)  9.00e-02 -2.60e-01
# 現地気圧(hPa)  9.55e-02 -2.45e-01
# 日射量(MJ/㎡) -4.78e-02 -1.76e-01
# 天気        -3.93e-01  5.47e-01
# 視程(km)     1.00e+00 -2.52e-01
# 雲量(10分比)  -2.52e-01  1.00e+00

# %% [markdown]
# ### 相関係数の大きい要素のみ表示

# %%
df_corr.applymap(lambda x: x if abs(x) > 0.3 else "---")
# Out:
#           気温(℃) 降水量(mm) 降雪(cm) 積雪(cm) 日照時間(時間) 風速(m/s)   風向 露点温度(℃) 蒸気圧(hPa)  \
# 気温(℃)         1     ---    ---  -0.41      ---     ---  ---     0.9     0.87
# 降水量(mm)     ---       1    ---    ---      ---     ---  ---     ---      ---
# 降雪(cm)      ---     ---      1    ---      ---     ---  ---     ---      ---
# 積雪(cm)    -0.41     ---    ---      1      ---     ---  ---   -0.39     -0.3
# 日照時間(時間)    ---     ---    ---    ---        1     ---  ---     ---      ---
# 風速(m/s)     ---     ---    ---    ---      ---       1  ---     ---      ---
# 風向          ---     ---    ---    ---      ---     ---    1     ---      ---
# 露点温度(℃)     0.9     ---    ---  -0.39      ---     ---  ---       1     0.97
# 蒸気圧(hPa)   0.87     ---    ---   -0.3      ---     ---  ---    0.97        1
# 相対湿度(％)     ---     ---    ---    ---    -0.62    -0.4  ---     ---      ---
# 海面気圧(hPa) -0.53     ---    ---    ---      ---     ---  ---   -0.52    -0.53
# 現地気圧(hPa) -0.33     ---    ---    ---      ---     ---  ---   -0.35    -0.36
# 日射量(MJ/㎡)  0.33     ---    ---    ---     0.85     ---  ---     ---      ---
# 天気          ---     ---    ---    ---      ---     ---  ---     ---      ---
# 視程(km)      ---     ---    ---    ---      ---     ---  ---     ---      ---
# 雲量(10分比)    ---     ---    ---    ---    -0.33     ---  ---     ---      ---
#
#           相対湿度(％) 海面気圧(hPa) 現地気圧(hPa) 日射量(MJ/㎡)    天気 視程(km) 雲量(10分比)
# 気温(℃)         ---     -0.53     -0.33      0.33   ---    ---      ---
# 降水量(mm)       ---       ---       ---       ---   ---    ---      ---
# 降雪(cm)        ---       ---       ---       ---   ---    ---      ---
# 積雪(cm)        ---       ---       ---       ---   ---    ---      ---
# 日照時間(時間)    -0.62       ---       ---      0.85   ---    ---    -0.33
# 風速(m/s)      -0.4       ---       ---       ---   ---    ---      ---
# 風向            ---       ---       ---       ---   ---    ---      ---
# 露点温度(℃)       ---     -0.52     -0.35       ---   ---    ---      ---
# 蒸気圧(hPa)      ---     -0.53     -0.36       ---   ---    ---      ---
# 相対湿度(％)         1       ---       ---     -0.66  0.37    ---      ---
# 海面気圧(hPa)     ---         1      0.98       ---   ---    ---      ---
# 現地気圧(hPa)     ---      0.98         1       ---   ---    ---      ---
# 日射量(MJ/㎡)   -0.66       ---       ---         1   ---    ---      ---
# 天気           0.37       ---       ---       ---     1  -0.39     0.55
# 視程(km)        ---       ---       ---       --- -0.39      1      ---
# 雲量(10分比)      ---       ---       ---       ---  0.55    ---        1

# %% [markdown]
# ### 降水量と他データとの相関

# %%
pd.reset_option("display.precision")
pd.DataFrame(df_corr["降水量(mm)"])
# Out:
#             降水量(mm)
# 気温(℃)      0.046919
# 降水量(mm)    1.000000
# 降雪(cm)     0.042667
# 積雪(cm)    -0.016431
# 日照時間(時間)  -0.082510
# 風速(m/s)   -0.004945
# 風向        -0.015147
# 露点温度(℃)    0.113077
# 蒸気圧(hPa)   0.124163
# 相対湿度(％)    0.167913
# 海面気圧(hPa) -0.108103
# 現地気圧(hPa) -0.107875
# 日射量(MJ/㎡) -0.080282
# 天気         0.179307
# 視程(km)    -0.092218
# 雲量(10分比)   0.078836

# %% [markdown]
# ## → <font color="red">残念ながら降水量と相関の強いデータはなし</font>

# %% [markdown]
# ***

# %% [markdown]
# # ２．次ステップの方向づけ
# * 相関係数からでは降水量の予測に適した要素を見つけられなかった。
# * 決定木から降水量に関連性の強い要素を見つける
# * 関連性の強い要素から降水量を推定する<br>
#
# ### 学習設定
# * 決定木の階層（＝if文のネストの深さ）は１０とする
# * １か月分のデータをテストデータとする。

# %%
MAX_NEST_DEPTH = 10
TEST_DATA_LENGTH = 24 * 30  # 1か月分をテストデータとする

# %% [markdown]
# ### データ準備

# %%
src = np.array(df.drop('降水量(mm)', axis=1))
src = np.delete(src, -1, axis = 0)  # 最終のデータは予測には使用しない（できない）ため削除

# %%
target = np.array(df['降水量(mm)'])
target = np.delete(target, 0, axis = 0)  # 先頭のデータは予測できないため削除
#target = np.round(target) # DecisionTreeClassifierは整数である必要あり。
target = [(True if t > min(target) else False) for t in target] # 雨が少しでも降れば「降雨あり」

# %%
plt.subplots(figsize=(13, 5))
index = [datetime.datetime.strptime(i, '%Y/%m/%d %H:%M') for i in df.index]
plt.plot(index, df['降水量(mm)'].values)
plt.show()

# %% [markdown]
# 　　　　　　　　　　　　　　　　　　　　　　　　　１時間ごとの降雨量

# %% [markdown]
# ***
# ## トレーニング開始

# %%
src_train = src[:-TEST_DATA_LENGTH]
target_train = target[:-TEST_DATA_LENGTH]

# %% [markdown]
# ### 決定木を実行

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier(max_depth=MAX_NEST_DEPTH)
#clf = tree.DecisionTreeRegressor(max_depth=3)  # 降水量が小数でもOKだが..これは一体何？
clf = clf.fit(src_train, target_train)

# %%
# 作成した決定木を可視化 (pydotplus パッケージを利用)
import pydotplus
from sklearn.externals.six import StringIO
dot_data = StringIO()
tree.export_graphviz(clf, out_file=dot_data)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

# %%
from IPython.display import Image
Image(graph.create_png())

# %%
for (i, n) in enumerate(df.drop('降水量(mm)', axis=1).columns):
    print(i, n)
# Out:
# 0 気温(℃)
# 1 降雪(cm)
# 2 積雪(cm)
# 3 日照時間(時間)
# 4 風速(m/s)
# 5 風向
# 6 露点温度(℃)
# 7 蒸気圧(hPa)
# 8 相対湿度(％)
# 9 海面気圧(hPa)
# 10 現地気圧(hPa)
# 11 日射量(MJ/㎡)
# 12 天気
# 13 視程(km)
# 14 雲量(10分比)

# %% [markdown]
# ### トレーニングした結果

# %%
predicted = clf.predict(src_train)
print(len(target_train), "回中", sum(predicted == target_train), "回で的中（", round(sum(predicted == target_train) / len(target_train) * 100), "%）")
# Out:
# 6598 回中 6429 回で的中（ 97.0 %）

# %% [markdown]
# * 現在の天気が1時間後の降雨の有無の判断に最も重要である
# * 次に相対湿度を見ることで降雨を判定可能である。

# %% [markdown]
# ***
# ## １か月の降雨を予測する

# %%
src_test = src[-TEST_DATA_LENGTH:]
target_test = target[-TEST_DATA_LENGTH:]
predicted = clf.predict(src_test)

# %%
fig, ax1 = plt.subplots(figsize=(13, 5))
index = [datetime.datetime.strptime(i, '%Y/%m/%d %H:%M') for i in df.index[-TEST_DATA_LENGTH:]]
ax1.plot(index, predicted, color='r')
ax2 = ax1.twinx()
ax2.plot(index, df['降水量(mm)'].values[-TEST_DATA_LENGTH:])
plt.show()

# %% [markdown]
# <font color="blue">青線：降水量</font>
# <font color="red">赤線：1時間後の雨を予測した結果</font>

# %% [markdown]
# ### 予測した結果

# %%
print(TEST_DATA_LENGTH, "回中", sum(predicted == target_test), "回で的中（", round(sum(predicted == target_test) / len(target_test) * 100), "%）")
# Out:
# 720 回中 682 回で的中（ 95.0 %）

# %%
pair = np.array([target_test, predicted]).T
result = [sum(i[0] == i[1] and i[0] == True for i in pair),    # 降雨あり、予測もありの回数
          sum(i[0] == i[1] and i[0] == False for i in pair),   # 降雨なし、予測もなしの回数
          sum(i[0] == False and i[1] == True for i in pair),   # 降雨なし、予測はありの回数
          sum(i[0] == True and i[1] == False for i in pair)]   # 降雨あり、予測はなしの回数

# %%
pd.DataFrame(np.array([["有", "無", "無", "有"], ["有", "無", "有", "無"], result]).T, columns=["実際", "予測", "回数"])
# Out:
#   実際 予測   回数
# 0  有  有   10
# 1  無  無  672
# 2  無  有   30
# 3  有  無    8

# %% [markdown]
# ***
# # ３．結果
# * 相関係数では相関のない要素でも、決定木を使用した要素抽出で的中率は95%となった。
# * 決定木による予測では「天気」「相対湿度」による影響が大きいと判断したが、現実的にも妥当な判定条件であった。
# * 決定木の深さによる過学習や、季節の影響等を考慮すべきである。
